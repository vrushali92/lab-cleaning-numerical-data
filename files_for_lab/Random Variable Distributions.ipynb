# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
numerical_df = pd.read_csv("numerical.csv")
numerical_df = numerical_df.drop(["Unnamed: 0"], axis = 1)
numerical_df
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %% [markdown]
# # Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.

# %%
sns.displot(numerical_df["customer_lifetime_value"], kde = True, bins = 20)

# %%
sns.displot(numerical_df["income"], kde = True, bins = 20)

# %%
sns.displot(numerical_df["monthly_premium_auto"], kde = True, bins = 20)

# %%
sns.displot(numerical_df["months_since_last_claim"], kde = True, bins = 20)

# %%
sns.displot(numerical_df["number_of_policies"], kde = True, bins = 20)

# %%
sns.displot(numerical_df["total_claim_amount"], kde = True, bins = 20)

# %%
numerical_df.columns
# Out:
# Index(['customer_lifetime_value', 'income', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'total_claim_amount',
#        'customer_lifetime_value_transformed',
#        'total_claim_amount_transformed'],
#       dtype='object')

# %%
sns.displot(numerical_df["months_since_policy_inception"], kde = True, bins = 20)

# %% [markdown]
# months_since_policy_inception column has close to normal distribution. Customer_lifetime_value has close to exponential curve.

# %% [markdown]
# # Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %%
def log_transfom_clean(x):
    if x>0:
        return np.log(x)
    else:
        return np.NAN

# %%
numerical_df.columns
# Out:
# Index(['customer_lifetime_value', 'income', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'total_claim_amount',
#        'customer_lifetime_value_transformed',
#        'total_claim_amount_transformed'],
#       dtype='object')

# %%
sns.displot(numerical_df.income.apply(log_transfom_clean), kde = True)

# %%
sns.displot(numerical_df.monthly_premium_auto.apply(log_transfom_clean), kde = True)

# %%
sns.displot(numerical_df.months_since_last_claim.apply(log_transfom_clean), kde = True)

# %%
sns.displot(numerical_df.months_since_policy_inception.apply(log_transfom_clean), kde = True)

# %%
sns.displot(numerical_df.number_of_open_complaints.apply(log_transfom_clean), kde = True)

# %%
sns.displot(numerical_df.total_claim_amount_transformed, kde = True)

# %%
sns.displot(numerical_df.customer_lifetime_value_transformed, kde = True)

# %%
# After log transformation, months_since_policy_inception and total claim amount show curve close to exponential curve.
